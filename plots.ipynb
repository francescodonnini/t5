# %%
import numpy as np
import pandas as pd

# %%
trivial = [pd.read_csv(f'data/20250225/1/resnet/trivial_augment/history_{i}.csv') for i in range(5)]

# %%
trivial[4].plot(x='Unnamed: 0', y=['loss', 'val_loss'])
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
val_loss = np.mean([df['val_accuracy'].iloc[-1] for df in trivial])
val_loss
# Out:
# np.float64(0.8144057273864747)

# %%
trivial[0].plot(x='epoch', y='val_accuracy', legend=False, figsize=(12, 5))

# %%
cutout = [pd.read_csv(f'data/20250225/1/resnet/cutout/history_{i}.csv') for i in range(5)]

# %%
val_loss = np.mean([df['val_accuracy'].iloc[-1] for df in cutout])
val_loss
# Out:
# np.float64(0.7989112138748169)
